# %%
import numpy as np
W = np.array([1,2,1])
b = np.array([1])
X = np.arange(12).reshape(4,3)

def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
X@W + b
# Out:
# array([ 5, 17, 29, 41])

# %%
import matplotlib.pyplot as plt

X = np.arange(-50,50)
Y = sigmoid(X)

plt.plot(X,Y)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
iris = np.loadtxt('iris.csv', delimiter=',', skiprows=1, usecols=[0,1,2,3])
X = iris[:,:3] #입력값
Y = iris[:,[3]] # 목표값

W = tf.Variable(tf.random.normal([3,1])) #가중치
B = tf.Variable(0.0)                     # 절편값

lr = 0.01  # 학습률
losses = [] # 오차값

for epoch in range(1000):
    with tf.GradientTape() as tape:
        pred_y = X@W +B                                  #출력값
        loss = tf.reduce_sum((Y-pred_y )**2) /len(Y)     # MSE
        
        grads = tape.gradient(loss,[W,B]) # 기울기 계산 미분법 계산
        W.assign_sub(lr*grads[0])
        B.assign_sub(lr*grads[1])
        
        losses.append(loss.numpy())
        
        if(epoch +1) % 100==0:
            print(epoch, loss.numpy())
            plt.figure()
            plt.plot(losses)
            plt.show()

            
print(W)
print(B)
# Out:
# 99 0.08985666
# 199 0.07816202
# 299 0.06903475
# 399 0.06188307
# 499 0.05627913
# 599 0.051887784
# 699 0.048446465
# 799 0.04574942
# 899 0.043635506
# 999 0.041978456
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[-0.0505691 ],
#        [-0.01250041],
#        [ 0.431117  ]], dtype=float32)>
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=-0.0858691>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([1,2,3])
y= np.array([3,5,7])
model = Sequential()

# %%
model.add(Dense(1, input_shape=(1,),activation='linear'))
model.compile(loss='mse', optimizer='sgd')
model.fit(x, y, epochs= 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 344ms/step - loss: 45.8742
# Epoch 2/100
# 1/1 [==============================] - 0s 5ms/step - loss: 36.2618
# Epoch 3/100
# 1/1 [==============================] - 0s 4ms/step - loss: 28.6638
# Epoch 4/100
# 1/1 [==============================] - 0s 5ms/step - loss: 22.6579
# Epoch 5/100
# 1/1 [==============================] - 0s 12ms/step - loss: 17.9106
# Epoch 6/100
# 1/1 [==============================] - 0s 5ms/step - loss: 14.1581
# Epoch 7/100
# 1/1 [==============================] - 0s 6ms/step - loss: 11.1919
# Epoch 8/100
# 1/1 [==============================] - 0s 11ms/step - loss: 8.8473
# Epoch 9/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9940
# Epoch 10/100
# 1/1 [==============================] - 0s 7ms/step - loss: 5.5291
# Epoch 11/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3712
# Epoch 12/100
# 1/1 [==============================] - 0s 8ms/step - loss: 3.4559
# ...

# %%
model.predict(np.array([4,5]))
# Out:
# array([[ 8.905576],
#        [10.850925]], dtype=float32)
